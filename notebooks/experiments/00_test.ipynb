# %%
# Verificación de instalación
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

print("✅ Todas las librerías funcionan correctamente")
print(f"📦 Pandas version: {pd.__version__}")
print(f"📦 NumPy version: {np.__version__}")

# Crear datos de prueba
data = {
    'libro': ['Harry Potter', 'El Señor de los Anillos', '1984', 'Cien Años de Soledad'],
    'rating': [5, 4, 5, 3]
}
df = pd.DataFrame(data)

print("\n📊 DataFrame de prueba:")
print(df)

# Gráfico simple
plt.figure(figsize=(8, 5))
plt.bar(df['libro'], df['rating'], color='skyblue')
plt.xlabel('Libro')
plt.ylabel('Rating')
plt.title('Ratings de Ejemplo')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# ✅ Todas las librerías funcionan correctamente
# 📦 Pandas version: 2.3.3
# 📦 NumPy version: 2.4.0
#
# 📊 DataFrame de prueba:
#                      libro  rating
# 0             Harry Potter       5
# 1  El Señor de los Anillos       4
# 2                     1984       5
# 3     Cien Años de Soledad       3
